# %%
import io
import re

import subprocess
import requests

# %%
course_id = 'SPR'

# %%
# Vimeo API to download captions
def download_caption(video_path, course_id, output_name):
    m = re.findall('video\/[0-9]{9}\?', video_path)
    video_id = re.split('\/|\?', m[0])[1]
    
    
    # command = "curl https://api.vimeo.com/videos/777833276/texttracks -H \"Authorization: bearer 4d19d6b7532bcfa4a2f7e5307f67db2b\""
    # video_id = '777833276'
    result = requests.get(f'https://api.vimeo.com/videos/{video_id}/texttracks', headers={'Authorization': 'Bearer 4d19d6b7532bcfa4a2f7e5307f67db2b'})
    transcript_url = result.json()['data'][0]['link']

    transcript_content = requests.get(transcript_url).content
    open(f"./{course_id}/transcripts/{output_name}.vtt", "wb").write(transcript_content)

    return video_id

# download_caption("https://player.vimeo.com/video/777833276?h=204360c85", course_id)

# %%
file1 = open(f'./{course_id}/library.md', 'r')
lines = file1.readlines()
  
entryLock = 0
playlist = []
keys = ['file', 'url', 'title', 'duration']
entry = dict({})

download_captions = True

# Strips the newline character
for line in lines:
    # print('line', line)
    if entryLock >= 0 and entryLock <= 3:
        fixedLine = re.sub('\n', '', line)
        
        if entryLock == 1:
            print(fixedLine)
            m = re.findall('https\:\/\/player\.vimeo\.com\/video\/[0-9]{9}\?h\=[0-9a-z]{10}', fixedLine)
            fixedLine = m[0]
            
            if(download_captions == True):
                download_caption(fixedLine, course_id, output_name=entry['file'])
        
        entry[keys[entryLock]] = fixedLine
        
    
    if len(line) == 1:
        entryLock = 0
        entry = dict({})
    else:
        entryLock+=1
     

    
    if entryLock == 3:
        playlist.append(entry)
        
playlist
# Out:
# <iframe src="https://player.vimeo.com/video/797174163?h=c8f7d92f8d" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/797174300?h=62934b3418&amp;badge=0&amp;autopause=0&amp;player_id=0&amp;app_id=58479" width="1920" height="1080" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen title="M1c2"></iframe>
# <iframe src="https://player.vimeo.com/video/778894760?h=b6d039762b" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778897101?h=2f711b6793" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/795400358?h=25ec9be6a2" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/795396435?h=f2c13430a3" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/795403602?h=6e9909827e" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778897448?h=c5da8a109a" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778897577?h=3da099dae1" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778900218?h=c8cb7e811c" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778900642?h=98b8541acc" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778901311?h=838c0fecd2" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778903929?h=745471479f" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778904759?h=c0ef1e4bff" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778905134?h=0d537170eb" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778905893?h=a65f475648" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778906156?h=ef16a54023" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778906584?h=8cad48641c" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778906821?h=f106d22b92" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778907703?h=f514a36911" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778908269?h=15129b6aa0" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778908444?h=c0515e4ad1" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778911145?h=09f58864df" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778911299?h=f8dec4aa98" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778911488?h=b1e12c9606" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778911650?h=8ffd3e5fe7" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778911905?h=e105f3afca" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778912128?h=2e2c283882" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778912715?h=52743fda02" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778913279?h=fde4746bc8" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778913595?h=b0d76e583b" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778916013?h=7af1ce35a9" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778916227?h=10c34d23c9" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778916295?h=14791f2211" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778918561?h=9e26253bd2" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778919177?h=f75160449e" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778919410?h=429642ab93" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778919540?h=6e71382836" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778919751?h=67e7f5d1a4" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778922327?h=ef60405ef0" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778922769?h=0fe25ca32c" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/778923045?h=8b0c3cec9b" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/781753336?h=ed032c64d1" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/781753143?h=943e4a8fa2" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/777847396?h=ea2a141480" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/777847574?h=7b78849a21" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/777848031?h=b157e8e4b8" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/777849507?h=86f847067e" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/781759737?h=200c099273" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/781755173?h=a7cd83ad95" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/781755691?h=eb04328b21" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789265765?h=3b2ab8a303" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789265939?h=9ef29a7a46" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789266079?h=3fad1b8082" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789266252?h=118cbdc8cf" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789266412?h=0de6d81d3f" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789268973?h=24b7193ca3" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789266920?h=f41008a3e2" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789267475?h=0cd666805e" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789267651?h=1bb406f5b4" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789267827?h=da463eddc0" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/790618962?h=23af5569df" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/790625680?h=07c5f0db4d" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789268390?h=dad97b0c8c" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789268545?h=2e309f0b30" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# <iframe src="https://player.vimeo.com/video/789268626?h=d7aa36519a" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>
# [{'file': 'M1c1.mov',
#   'url': 'https://player.vimeo.com/video/797174163?h=c8f7d92f8d',
#   'title': 'Inferring with Statistics',
#   'duration': '01:59'},
#  {'file': 'M1c2.mov',
#   'url': 'https://player.vimeo.com/video/797174300?h=62934b3418',
#   'title': 'Statistics and Probability Theory',
#   'duration': '03:09'},
#  {'file': 's1-3-3.mov',
#   'url': 'https://player.vimeo.com/video/778894760?h=b6d039762b',
#   'title': 'Measures of Central Tendency',
#   'duration': '05:01'},
#  {'file': 's1-3-5.mov',
#   'url': 'https://player.vimeo.com/video/778897101?h=2f711b6793',
#   'title': 'Terminology: Statistic and Parameter',
#   'duration': '03:12'},
#  {'file': 'term1.mov',
#   'url': 'https://player.vimeo.com/video/795400358?h=25ec9be6a2',
#   'title': 'Sample Space, Events, Experiments, and Outcomes',
#   'duration': '05:31'},
#  {'file': 'term2.mov',
#   'url': 'https://player.vimeo.com/video/795396435?h=f2c13430a3',
#   'title': 'Random Variable',
#   'duration': '05:52'},
#  {'file': 'term3.mov',
#   'url': 'https://player.vimeo.com/video/795403602?h=6e9909827e',
#   'title': 'Probability Function',
#   'duration': '03:49'},
#  {'file': 's1-6-1.mov',
#   'url': 'https://player.vimeo.com/video/778897448?h=c5da8a109a',
#   'title': 'Example: Calculating Probability ',
#   'duration': '02:51'},
#  {'file': 's1-6-2.mov',
#   'url': 'https://player.vimeo.com/video/778897577?h=3da099dae1',
#   'title': 'Sets and Sample Spaces',
#   'duration': '13:31'},
#  {'file': 's1-7-1.mov',
#   'url': 'https://player.vimeo.com/video/778900218?h=c8cb7e811c',
#   'title': 'Overview of Random Variable',
#   'duration': '05:10'},
#  {'file': 's1-7-2.mov',
#   'url': 'https://player.vimeo.com/video/778900642?h=98b8541acc',
#   'title': 'Exercise: Calculating Probability',
#   'duration': '05:10 '},
#  {'file': 's1-7-3.mov',
#   'url': 'https://player.vimeo.com/video/778901311?h=838c0fecd2',
#   'title': 'Solution: Calculating Probability',
#   'duration': '09:55'},
#  {'file': 's1-8-1.mov',
#   'url': 'https://player.vimeo.com/video/778903929?h=745471479f',
#   'title': 'Probability Mass Function (PMF)',
#   'duration': '07:42'},
#  {'file': 's1-8-2.mov',
#   'url': 'https://player.vimeo.com/video/778904759?h=c0ef1e4bff',
#   'title': 'Probability Functions: PMF, PDF, and CDF',
#   'duration': '05:10 '},
#  {'file': 's1-9-1.mov',
#   'url': 'https://player.vimeo.com/video/778905134?h=0d537170eb',
#   'title': 'Cumulative Distribution Function (CDF)',
#   'duration': '08:44'},
#  {'file': 's1-9-2.mov',
#   'url': 'https://player.vimeo.com/video/778905893?h=a65f475648',
#   'title': 'Exercise: Cumulative Distribution Function',
#   'duration': '03:02'},
#  {'file': 's1-9-3.mov',
#   'url': 'https://player.vimeo.com/video/778906156?h=ef16a54023',
#   'title': 'Solution: Cumulative Distribution Function',
#   'duration': '06:38'},
#  {'file': 's1-9-4.mov',
#   'url': 'https://player.vimeo.com/video/778906584?h=8cad48641c',
#   'title': 'Exercise: Discrete Distribution',
#   'duration': '02:29'},
#  {'file': 's1-9-5.mov',
#   'url': 'https://player.vimeo.com/video/778906821?h=f106d22b92',
#   'title': 'Solution: Discrete Distribution',
#   'duration': '11:50'},
#  {'file': 's1-10-1.mov',
#   'url': 'https://player.vimeo.com/video/778907703?h=f514a36911',
#   'title': 'Moments: The Shape of a Distribution',
#   'duration': '06:32'},
#  {'file': 's1-10-2.mov',
#   'url': 'https://player.vimeo.com/video/778908269?h=15129b6aa0',
#   'title': 'Calculating Moments with Generating Functions',
#   'duration': '02:08'},
#  {'file': 's1-10-3.mov',
#   'url': 'https://player.vimeo.com/video/778908444?h=c0515e4ad1',
#   'title': 'Calculating the Expected Value',
#   'duration': '08:43'},
#  {'file': 's2-2-1.mov',
#   'url': 'https://player.vimeo.com/video/778911145?h=09f58864df',
#   'title': 'Random Variables as Maps',
#   'duration': '02:51'},
#  {'file': 's2-3-1.mov',
#   'url': 'https://player.vimeo.com/video/778911299?h=f8dec4aa98',
#   'title': 'Definite Integration for Distributions',
#   'duration': '04:19'},
#  {'file': 's2-4-1.mov',
#   'url': 'https://player.vimeo.com/video/778911488?h=b1e12c9606',
#   'title': 'Discrete vs Continuous Distributions',
#   'duration': '02:43'},
#  {'file': 's2-4-2.mov',
#   'url': 'https://player.vimeo.com/video/778911650?h=8ffd3e5fe7',
#   'title': 'The Normal Distribution, Variance, and Risk',
#   'duration': '03:12'},
#  {'file': 's2-4-3.mov',
#   'url': 'https://player.vimeo.com/video/778911905?h=e105f3afca',
#   'title': 'Syntax: Probability Distribution',
#   'duration': '02:44'},
#  {'file': 's2-5-1.mov',
#   'url': 'https://player.vimeo.com/video/778912128?h=2e2c283882',
#   'title': 'Cumulative Probability of a Normal Distribution',
#   'duration': '05:11'},
#  {'file': 's2-7-1.mov',
#   'url': 'https://player.vimeo.com/video/778912715?h=52743fda02',
#   'title': 'Overview of Standardization',
#   'duration': '06:00'},
#  {'file': 's2-7-2.mov',
#   'url': 'https://player.vimeo.com/video/778913279?h=fde4746bc8',
#   'title': '68%-95%-99.7% Rule',
#   'duration': '02:56'},
#  {'file': 's2-8-1.mov',
#   'url': 'https://player.vimeo.com/video/778913595?h=b0d76e583b',
#   'title': 'Exercise: Normal Distrubution',
#   'duration': '04:07'},
#  {'file': 's2-8-2.mov',
#   'url': 'https://player.vimeo.com/video/778916013?h=7af1ce35a9',
#   'title': 'Solution: Normal Distribution 1',
#   'duration': '04:37'},
#  {'file': 's2-8-3.mov',
#   'url': 'https://player.vimeo.com/video/778916227?h=10c34d23c9',
#   'title': 'The Standard Normal Distribution',
#   'duration': '01:55'},
#  {'file': 's2-8-4.mov',
#   'url': 'https://player.vimeo.com/video/778916295?h=14791f2211',
#   'title': 'Overview of Z-Score',
#   'duration': '03:18'},
#  {'file': 's2-9-1.mov',
#   'url': 'https://player.vimeo.com/video/778918561?h=9e26253bd2',
#   'title': 'Integrating the Standard Normal Distribution Function',
#   'duration': '06:47'},
#  {'file': 's2-9-2.mov',
#   'url': 'https://player.vimeo.com/video/778919177?h=f75160449e',
#   'title': 'Using the Z-Score Table',
#   'duration': '01:49'},
#  {'file': 's2-9-3.mov',
#   'url': 'https://player.vimeo.com/video/778919410?h=429642ab93',
#   'title': 'Standardizing a Normal Random Variable',
#   'duration': '02:22'},
#  {'file': 's2-9-4.mov',
#   'url': 'https://player.vimeo.com/video/778919540?h=6e71382836',
#   'title': 'Comparing Two Probabilities',
#   'duration': '04:19'},
#  {'file': 's2-9-5.mov',
#   'url': 'https://player.vimeo.com/video/778919751?h=67e7f5d1a4',
#   'title': 'Solution: Normal Distribution 2',
#   'duration': '09:25'},
#  {'file': 's2-10-1.mov',
#   'url': 'https://player.vimeo.com/video/778922327?h=ef60405ef0',
#   'title': 'Moments: The Shape of a Distribution',
#   'duration': '06:38'},
#  {'file': 's2-10-2.mov',
#   'url': 'https://player.vimeo.com/video/778922769?h=0fe25ca32c',
#   'title': 'Getting Started with R',
#   'duration': '02:48'},
#  {'file': 's2-10-3.mov',
#   'url': 'https://player.vimeo.com/video/778923045?h=8b0c3cec9b',
#   'title': 'Quantiles: Quartile, Decile, and Percentile',
#   'duration': '04:05'},
#  {'file': 's2-10-4.mov',
#   'url': 'https://player.vimeo.com/video/781753336?h=ed032c64d1',
#   'title': 'Plotting Data',
#   'duration': '03:22'},
#  {'file': 's2-10-5.mov',
#   'url': 'https://player.vimeo.com/video/781753143?h=943e4a8fa2',
#   'title': 'Comparing Two Distributions',
#   'duration': '03:05'},
#  {'file': 's2-11.mov',
#   'url': 'https://player.vimeo.com/video/777847396?h=ea2a141480',
#   'title': '-',
#   'duration': '04:18'},
#  {'file': 's2-12.mov',
#   'url': 'https://player.vimeo.com/video/777847574?h=7b78849a21',
#   'title': 'Formula for the Moment Generating Function',
#   'duration': '11:49'},
#  {'file': 's2-13.mov',
#   'url': 'https://player.vimeo.com/video/777848031?h=b157e8e4b8',
#   'title': '-',
#   'duration': '03:31'},
#  {'file': 's3-6-1.mov',
#   'url': 'https://player.vimeo.com/video/777849507?h=86f847067e',
#   'title': '-',
#   'duration': '01:07'},
#  {'file': 's3-6-2.mov',
#   'url': 'https://player.vimeo.com/video/781759737?h=200c099273',
#   'title': 'Regression to The Mean',
#   'duration': '03:15'},
#  {'file': 's3-8-1.mov',
#   'url': 'https://player.vimeo.com/video/781755173?h=a7cd83ad95',
#   'title': 'Multiple Linear Regression',
#   'duration': '08:38'},
#  {'file': 's3-8-2.mov',
#   'url': 'https://player.vimeo.com/video/781755691?h=eb04328b21',
#   'title': 'Fitting the Model',
#   'duration': '02:07'},
#  {'file': 'bayes1-1',
#   'url': 'https://player.vimeo.com/video/789265765?h=3b2ab8a303',
#   'title': 'Agenda for Bayes Theorem',
#   'duration': '02:59'},
#  {'file': 'bayes1-2',
#   'url': 'https://player.vimeo.com/video/789265939?h=9ef29a7a46',
#   'title': 'Review of Set Intersection and Union',
#   'duration': '04:56'},
#  {'file': 'bayes2-1',
#   'url': 'https://player.vimeo.com/video/789266079?h=3fad1b8082',
#   'title': 'Marginal and Joint Frequencies',
#   'duration': '05:25'},
#  {'file': 'bayes2-2',
#   'url': 'https://player.vimeo.com/video/789266252?h=118cbdc8cf',
#   'title': 'Joint Frequencies Explained',
#   'duration': '04:33'},
#  {'file': 'bayes2-3',
#   'url': 'https://player.vimeo.com/video/789266412?h=0de6d81d3f',
#   'title': 'Marginal and Joint Relative Frequencies',
#   'duration': '05:31'},
#  {'file': 'bayes5-1',
#   'url': 'https://player.vimeo.com/video/789268973?h=24b7193ca3',
#   'title': 'Deriving Bayes Theorem',
#   'duration': '10:33'},
#  {'file': 'bayes3-1',
#   'url': 'https://player.vimeo.com/video/789266920?h=f41008a3e2',
#   'title': 'Example: Inference with Bayesian Theorem (Part 1)',
#   'duration': '11:16 '},
#  {'file': 'bayes3-2',
#   'url': 'https://player.vimeo.com/video/789267475?h=0cd666805e',
#   'title': 'Example: Inference with Bayesian Theorem (Part 2)',
#   'duration': '04:22'},
#  {'file': 'bayes3-3',
#   'url': 'https://player.vimeo.com/video/789267651?h=1bb406f5b4',
#   'title': 'Example: Inference with Bayesian Theorem (Part 3)',
#   'duration': '03:12'},
#  {'file': 'bayes3-4',
#   'url': 'https://player.vimeo.com/video/789267827?h=da463eddc0',
#   'title': 'Odds Ratio, Likelihood Ratio, and Probability',
#   'duration': '03:25'},
#  {'file': 'bayes6-1',
#   'url': 'https://player.vimeo.com/video/790618962?h=23af5569df',
#   'title': 'Example: Inference with Bayesian Theorem (Part 4)',
#   'duration': '09:27'},
#  {'file': 'bayes6-2',
#   'url': 'https://player.vimeo.com/video/790625680?h=07c5f0db4d',
#   'title': 'Example: Inference with Bayesian Theorem (Part 5)',
#   'duration': '09:47'},
#  {'file': 'bayes4-1',
#   'url': 'https://player.vimeo.com/video/789268390?h=dad97b0c8c',
#   'title': 'Product of Two Probabilities (Combinatorics)',
#   'duration': '02:59 '},
#  {'file': 'bayes4-2',
#   'url': 'https://player.vimeo.com/video/789268545?h=2e309f0b30',
#   'title': 'Product of Two Probabilities (Distributions)',
#   'duration': '03:16'},
#  {'file': 'bayes4-3',
#   'url': 'https://player.vimeo.com/video/789268626?h=d7aa36519a',
#   'title': 'Posterior Distrubution Intuition',
#   'duration': '06:02'}]

# %%
m = re.findall('https\:\/\/player\.vimeo\.com\/video\/[0-9]{9}\?h\=[0-9a-z]{10}', '<iframe src="https://player.vimeo.com/video/768505245?h=2b87c99418" width="640" height="564" frameborder="0" allow="autoplay; fullscreen" allowfullscreen></iframe>')
m[0]
# Out:
# 'https://player.vimeo.com/video/768505245?h=2b87c99418'

# %% [markdown]
# ### Write on Image

# %%
# Importing the PIL library
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont

def writeOnImage(text, filename, index):
    # Open an Image
    img = Image.open(f'./{course_id}/split-clips/thumbnail-template.jpg')
    # Call draw Method to add 2D graphics in an image
    I1 = ImageDraw.Draw(img)
    # Custom font style and font size
    myFont = ImageFont.truetype('./resources/open-sans/OpenSans-Regular.ttf', 38)
    # Add Text to an image
    # I1.text((70, 485), f"{index}. {text}", font=myFont, fill =(255, 255, 255))
    I1.text((70, 485), f"{text}", font=myFont, fill =(255, 255, 255))
    # Display edited image
    # img.show()
    # Save the edited image
    img.save(f"./{course_id}/split-clips/{filename}.jpg")
    
# writeOnImage("Overview of Linear Algber", 1)

# %%
file1 = open(f'./{course_id}/library.md', 'r')
lines = file1.readlines()
  
entryLock = 0
playlist = []
keys = ['file', 'url', 'title', 'duration']
entry = dict({})
index = 1
# Strips the newline character
for line in lines:
    
    if entryLock >= 0 and entryLock <= 3:
        fixedLine = re.sub('\n', '', line)
        
        # if entryLock == 1:
        #     m = re.findall('https\:\/\/player\.vimeo\.com\/video\/[0-9]{9}\?h\=[0-9a-z]{10}', fixedLine)
        #     fixedLine = m[0]
        
        # entry[keys[entryLock]] = fixedLine
        
        if entryLock == 0:
            fileName = fixedLine
        if entryLock == 2:
            imageWords = fixedLine
        if entryLock == 3:
            writeOnImage(imageWords, fileName, index)
            index+=1
        
    
    if len(line) == 1:
        entryLock = 0
        entry = dict({})
    else:
        entryLock+=1
     

    
    if entryLock == 3:
        playlist.append(entry)
        
# playlist
